# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib as plt
# %matplotlib inline

# %%
covid_data = pd.read_csv("WHO-COVID-19-global-data.csv")
covid_data.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
covid_data.tail()
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 179167    2022-01-23           ZW  Zimbabwe       AFRO        218
# 179168    2022-01-24           ZW  Zimbabwe       AFRO         75
# 179169    2022-01-25           ZW  Zimbabwe       AFRO        287
# 179170    2022-01-26           ZW  Zimbabwe       AFRO        235
# 179171    2022-01-27           ZW  Zimbabwe       AFRO        167
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 179167            228179           4               5292
# 179168            228254           2               5294
# 179169            228541          11               5305
# 179170            228776          11               5316
# 179171            228943           5               5321

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179172 entries, 0 to 179171
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      179172 non-null  object
#  1   Country_code       178416 non-null  object
#  2   Country            179172 non-null  object
#  3   WHO_region         179172 non-null  object
#  4   New_cases          179172 non-null  int64
#  5   Cumulative_cases   179172 non-null  int64
#  6   New_deaths         179172 non-null  int64
#  7   Cumulative_deaths  179172 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 10.9+ MB

# %%
covid_data.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  1.791720e+05      1.791720e+05  179172.000000      179172.000000
# mean   2.012471e+03      4.630936e+05      31.371336       10028.023776
# std    1.460083e+04      2.562484e+06     164.663445       48033.182975
# min   -3.295200e+04      0.000000e+00     -92.000000           0.000000
# 25%    0.000000e+00      1.080000e+02       0.000000           1.000000
# 50%    2.000000e+01      7.605000e+03       0.000000         113.000000
# 75%    4.600000e+02      1.249802e+05       6.000000        2125.000000
# max    1.326265e+06      7.181266e+07    8786.000000      866039.000000

# %%
covid_data.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
covid_data.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
len(covid_data["Country"].unique())
# Out:
# 237

# %%
covid_data.loc[1 : 4, "Country"]
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
covid_data.loc[1 : 8, ["Country", "New_cases"]]
# Out:
#        Country  New_cases
# 1  Afghanistan          0
# 2  Afghanistan          0
# 3  Afghanistan          0
# 4  Afghanistan          0
# 5  Afghanistan          0
# 6  Afghanistan          0
# 7  Afghanistan          0
# 8  Afghanistan          0

# %%
covid_data["Country"] == "United States of America"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 179167    False
# 179168    False
# 179169    False
# 179170    False
# 179171    False
# Name: Country, Length: 179172, dtype: bool

# %%
covid_data[covid_data["Country"] == "United States of America"]
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 170856    2020-01-03           US  United States of America       AMRO
# 170857    2020-01-04           US  United States of America       AMRO
# 170858    2020-01-05           US  United States of America       AMRO
# 170859    2020-01-06           US  United States of America       AMRO
# 170860    2020-01-07           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 171607    2022-01-23           US  United States of America       AMRO
# 171608    2022-01-24           US  United States of America       AMRO
# 171609    2022-01-25           US  United States of America       AMRO
# 171610    2022-01-26           US  United States of America       AMRO
# 171611    2022-01-27           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
(171611 - 170856) + 1
# Out:
# 756

# %%
covid_data[covid_data["New_deaths"] > 1000]
# Out:
#        Date_reported Country_code                           Country  \
# 6322      2020-10-03           AR                         Argentina
# 18393     2020-09-08           BO  Bolivia (Plurinational State of)
# 21307     2020-05-21           BR                            Brazil
# 21309     2020-05-23           BR                            Brazil
# 21310     2020-05-24           BR                            Brazil
# ...              ...          ...                               ...
# 171605    2022-01-21           US          United States of America
# 171606    2022-01-22           US          United States of America
# 171607    2022-01-23           US          United States of America
# 171610    2022-01-26           US          United States of America
# 171611    2022-01-27           US          United States of America
#
#        WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
covid_data.loc[covid_data["New_deaths"] > 1000, ["New_deaths", "Country"]]
# Out:
#         New_deaths                           Country
# 6322          3351                         Argentina
# 18393         1610  Bolivia (Plurinational State of)
# 21307         1179                            Brazil
# 21309         1188                            Brazil
# 21310         1001                            Brazil
# ...            ...                               ...
# 171605        2974          United States of America
# 171606        2575          United States of America
# 171607        3546          United States of America
# 171610        2750          United States of America
# 171611        3176          United States of America
#
# [913 rows x 2 columns]

# %%
covid_data.loc[(covid_data["Country_code"] == "US") & (covid_data["New_deaths"] > 1000)]
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 170947    2020-04-03           US  United States of America       AMRO
# 170948    2020-04-04           US  United States of America       AMRO
# 170949    2020-04-05           US  United States of America       AMRO
# 170950    2020-04-06           US  United States of America       AMRO
# 170951    2020-04-07           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 171605    2022-01-21           US  United States of America       AMRO
# 171606    2022-01-22           US  United States of America       AMRO
# 171607    2022-01-23           US  United States of America       AMRO
# 171610    2022-01-26           US  United States of America       AMRO
# 171611    2022-01-27           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
covid_data.loc[covid_data["Country_code"] == "US", ["New_cases"]].max()
# Out:
# New_cases    1326265
# dtype: int64

# %%
covid_data.loc[covid_data["Country_code"] == "US", ["New_cases"]].min()
# Out:
# New_cases    0
# dtype: int64

# %%
covid_data.loc[covid_data["Country_code"] == "US", ["New_cases"]].sum()
# Out:
# New_cases    71812665
# dtype: int64

# %%
covid_data.loc[covid_data["Country_code"] == "US", ["Cumulative_cases"]].max()
# Out:
# Cumulative_cases    71812665
# dtype: int64

# %%
covid_data["New_deaths"].idxmax()
# Out:
# 45925

# %%
covid_data.iloc[45925]
# Out:
# Date_reported        2021-07-21
# Country_code                 EC
# Country                 Ecuador
# WHO_region                 AMRO
# New_cases                  1634
# Cumulative_cases         477946
# New_deaths                 8786
# Cumulative_deaths         30744
# Name: 45925, dtype: object

# %%
covid_data[covid_data["New_deaths"] == 8786]
# Out:
#       Date_reported Country_code  Country WHO_region  New_cases  \
# 45925    2021-07-21           EC  Ecuador       AMRO       1634
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 45925            477946        8786              30744

# %%
covid_data["pct_cases"] = (covid_data["New_cases"] / covid_data["Cumulative_cases"]) * 100
covid_data["pct_cases"]
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 179167    0.095539
# 179168    0.032858
# 179169    0.125579
# 179170    0.102721
# 179171    0.072944
# Name: pct_cases, Length: 179172, dtype: float64

# %%
covid_data[covid_data["pct_cases"] > 50]
# Out:
#        Date_reported Country_code         Country WHO_region  New_cases  \
# 52        2020-02-24           AF     Afghanistan       EMRO          5
# 822       2020-03-09           AL         Albania       EURO          2
# 830       2020-03-17           AL         Albania       EURO          9
# 1565      2020-02-25           DZ         Algeria       AFRO          5
# 2893      2021-09-19           AS  American Samoa       WPRO          1
# ...              ...          ...             ...        ...        ...
# 177735    2020-03-18           ZM          Zambia       AFRO          6
# 177744    2020-03-27           ZM          Zambia       AFRO         10
# 177747    2020-03-30           ZM          Zambia       AFRO         19
# 178493    2020-03-20           ZW        Zimbabwe       AFRO          1
# 178562    2020-05-28           ZW        Zimbabwe       AFRO         76
#
#         Cumulative_cases  New_deaths  Cumulative_deaths   pct_cases
# ...
